# %% [markdown]
# # Cluster Analysis

# %% [markdown]
# ## Objectives
#
# * Fit and evaluate a cluster model to group similar data
# * Understand the profile for each cluster
#
#
# ## Inputs
#
# * outputs/datasets/collection/SalesRecord.csv
# * Instructions on which variables to use for data cleaning and feature engineering. They are found in their respective notebooks.
#
# ## Outputs
#
# * Cluster Pipeline
# * Train Set
# * Most important features to define a cluster plot
# * Clusters Profile Description
# * Cluster Silhouette

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/House-Sales/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the parent of current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/House-Sales'

# %% [markdown]
# ---

# %% [markdown]
# # Load Data

# %%
import pandas as pd
df = (pd.read_csv("outputs/datasets/collection/SalesRecord.csv")
      .drop(['EnclosedPorch', 'WoodDeckSF', 'SalePrice'], axis=1)
      )
print(df.shape)
df.head(3)
# Out:
# (1460, 21)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
#
#    BsmtUnfSF  GarageArea GarageFinish  GarageYrBlt  ...  KitchenQual LotArea  \
# 0        150         548          RFn       2003.0  ...           Gd    8450
# 1        284         460          RFn       1976.0  ...           TA    9600
# 2        434         608          RFn       2001.0  ...           Gd   11250
#
#    LotFrontage  MasVnrArea  OpenPorchSF  OverallCond  OverallQual  \
# 0         65.0       196.0           61            5            7
# 1         80.0         0.0            0            8            6
# 2         68.0       162.0           42            5            7
#
#    TotalBsmtSF  YearBuilt  YearRemodAdd
# 0          856       2003          2003
# 1         1262       1976          1976
# 2          920       2001          2002
#
# [3 rows x 21 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Cluster Pipeline with all data

# %% [markdown]
# ##  ML Cluster Pipeline

# %%
from sklearn.pipeline import Pipeline
from feature_engine.selection import SmartCorrelatedSelection
from feature_engine.imputation import CategoricalImputer
from feature_engine.imputation import MeanMedianImputer
from feature_engine.selection import DropFeatures
from feature_engine.encoding import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans


def PipelineCluster():
    pipeline_base = Pipeline([
         ('median', MeanMedianImputer(imputation_method='median',
                                     variables=['2ndFlrSF', 'BedroomAbvGr','GarageYrBlt', 
                                                'LotFrontage', 'MasVnrArea'])),

        ('categorical_imputer', CategoricalImputer(imputation_method='missing',
                                                  fill_value='Missing',
                                                  variables=['GarageFinish', 'BsmtFinType1'])),
        
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary',
                                                     variables=['BsmtExposure', 'GarageFinish', 'KitchenQual', 'BsmtFinType1'])),
        ("scaler", StandardScaler()),

        ("PCA", PCA(n_components=21, random_state=0)),

        ("model", KMeans(n_clusters=50, random_state=0)),
        
        ('drop_features', DropFeatures(features_to_drop = ['EnclosedPorch', 'WoodDeckSF',])),

    ])
    return pipeline_base

# %% [markdown]
# ## Principal Component Analysis (PCA)

# %%
pipeline_cluster = PipelineCluster()
pipeline_pca = Pipeline(pipeline_cluster.steps[:-2])
df_pca = pipeline_pca.fit_transform(df)

print(df_pca.shape,'\n', type(df_pca))
# Out:
# (1460, 21)
#  <class 'numpy.ndarray'>

# %% [markdown]
# Apply PCA separately to the scaled data

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

n_components = 12


def pca_components_analysis(df_pca, n_components):
    pca = PCA(n_components=n_components).fit(df_pca)
    x_PCA = pca.transform(df_pca)  # array with transformed PCA

    ComponentsList = ["Component " + str(number)
                      for number in range(n_components)]
    dfExplVarRatio = pd.DataFrame(
        data=np.round(100 * pca.explained_variance_ratio_, 3),
        index=ComponentsList,
        columns=['Explained Variance Ratio (%)'])

    dfExplVarRatio['Accumulated Variance'] = dfExplVarRatio['Explained Variance Ratio (%)'].cumsum(
    )

    PercentageOfDataExplained = dfExplVarRatio['Explained Variance Ratio (%)'].sum(
    )

    print(
        f"* The {n_components} components explain {round(PercentageOfDataExplained,2)}% of the data \n")
    plt.figure(figsize=(9, 6))
    sns.lineplot(data=dfExplVarRatio,  marker="o")
    plt.xticks(rotation=90)
    plt.yticks(np.arange(0, 110, 10))
    plt.show()


pca_components_analysis(df_pca=df_pca, n_components=n_components)
# Out:
# * The 12 components explain 88.13% of the data

# %%
pca_components_analysis(df_pca=df_pca,n_components=6)
# Out:
# * The 6 components explain 65.05% of the data

# %% [markdown]
# ## Elbow Method and Silhouette Score

# %%
pipeline_cluster = PipelineCluster()
pipeline_analysis = Pipeline(pipeline_cluster.steps[:-1])
df_analysis = pipeline_analysis.fit_transform(df)

print(df_analysis.shape,'\n', type(df_analysis))
# Out:
# (1460, 50)
#  <class 'numpy.ndarray'>

# %%
from yellowbrick.cluster import KElbowVisualizer

visualizer = KElbowVisualizer(KMeans(random_state=0), k=(1,11)) # 11 is not inclusive, it will plot until 10
visualizer.fit(df_analysis) 
visualizer.show() 
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
from yellowbrick.cluster import SilhouetteVisualizer

# 6 is not inclusive, it will stop at 5
n_cluster_start, n_cluster_stop = 2, 6

print("=== Average Silhouette Score for different number of clusters ===")
visualizer = KElbowVisualizer(KMeans(random_state=0), k=(
    n_cluster_start, n_cluster_stop), metric='silhouette')
visualizer.fit(df_analysis)
visualizer.show()
plt.show()
print("\n")


for n_clusters in np.arange(start=n_cluster_start, stop=n_cluster_stop):

    print(f"=== Silhouette plot for {n_clusters} Clusters ===")
    visualizer = SilhouetteVisualizer(estimator=KMeans(n_clusters=n_clusters, random_state=0),
                                      colors='yellowbrick')
    visualizer.fit(df_analysis)
    visualizer.show()
    plt.show()
    print("\n")
# Out:
# === Average Silhouette Score for different number of clusters ===
# === Silhouette plot for 2 Clusters ===
# === Silhouette plot for 3 Clusters ===
# === Silhouette plot for 4 Clusters ===
# === Silhouette plot for 5 Clusters ===

# %% [markdown]
# ## Fit Cluster Pipeline

# %%
X = df.copy()
print(X.shape)
X.head(10)
# Out:
# (1460, 21)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
# 3       961       NaN           NaN           No         216          ALQ
# 4      1145       NaN           4.0           Av         655          GLQ
# 5       796     566.0           1.0           No         732          GLQ
# 6      1694       0.0           3.0           Av        1369          GLQ
# 7      1107     983.0           3.0           Mn         859          ALQ
# 8      1022     752.0           2.0           No           0          Unf
# 9      1077       0.0           2.0           No         851          GLQ
#
#    BsmtUnfSF  GarageArea GarageFinish  GarageYrBlt  ...  KitchenQual LotArea  \
# 0        150         548          RFn       2003.0  ...           Gd    8450
# 1        284         460          RFn       1976.0  ...           TA    9600
# 2        434         608          RFn       2001.0  ...           Gd   11250
# 3        540         642          Unf       1998.0  ...           Gd    9550
# 4        490         836          RFn       2000.0  ...           Gd   14260
# 5         64         480          Unf       1993.0  ...           TA   14115
# 6        317         636          RFn       2004.0  ...           Gd   10084
# 7        216         484          NaN       1973.0  ...           TA   10382
# 8        952         468          Unf       1931.0  ...           TA    6120
# 9        140         205          RFn       1939.0  ...           TA    7420
#
#    LotFrontage  MasVnrArea  OpenPorchSF  OverallCond  OverallQual  \
# 0         65.0       196.0           61            5            7
# 1         80.0         0.0            0            8            6
# 2         68.0       162.0           42            5            7
# 3         60.0         0.0           35            5            7
# 4         84.0       350.0           84            5            8
# 5         85.0         0.0           30            5            5
# 6         75.0       186.0           57            5            8
# 7          NaN       240.0          204            6            7
# 8         51.0         0.0            0            5            7
# 9         50.0         0.0            4            6            5
#
#    TotalBsmtSF  YearBuilt  YearRemodAdd
# 0          856       2003          2003
# 1         1262       1976          1976
# 2          920       2001          2002
# 3          756       1915          1970
# 4         1145       2000          2000
# 5          796       1993          1995
# 6         1686       2004          2005
# 7         1107       1973          1973
# 8          952       1931          1950
# 9          991       1939          1950
#
# [10 rows x 21 columns]

# %%
pipeline_cluster = PipelineCluster()
pipeline_cluster.fit(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 pipeline_cluster = PipelineCluster()
# ----> 2 pipeline_cluster.fit(X)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/pipeline.py:346, in Pipeline.fit(self, X, y, **fit_params)
#     344     if self._final_estimator != 'passthrough':
#     345         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     348 return self
#
# File ~/.local/lib/python3.8/site-packages/feature_engine/selection/drop_features.py:64, in DropFeatures.fit(self, X, y)
#      46 """
#      47 This transformer does not learn any parameter.
#      48
#    (...)
#      61 self
#      62 """
#      63 # check input dataframe
# ---> 64 X = _is_dataframe(X)
#      66 # X[self.features_to_drops] calls to pandas to check if columns are
#      67 # present in the df.
#      68 X[self.features_to_drop]
#
# File ~/.local/lib/python3.8/site-packages/feature_engine/dataframe_checks.py:32, in _is_dataframe(X)
#      12 """
#      13 Checks if the input is a DataFrame and then creates a copy.
#      14
#    (...)
#      28     dataset of the user, accidentally.
#      29 """
#      31 if not isinstance(X, pd.DataFrame):
# ---> 32     raise TypeError("X is not a pandas dataframe. The dataset should be a "
#      33                     "pandas dataframe.")
#      35 return X.copy()
#
# TypeError: X is not a pandas dataframe. The dataset should be a pandas dataframe.

# %% [markdown]
# ## Add cluster predictions to dataset

# %% [markdown]
# We add a column "`Clusters`" (with the cluster pipeline predictions) to the dataset

# %%
X['Clusters'] = pipeline_cluster['model'].labels_
print(X.shape)
X.head(3)
# Out:
# (1460, 22)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
#
#    BsmtUnfSF  GarageArea GarageFinish  GarageYrBlt  ...  LotArea LotFrontage  \
# 0        150         548          RFn       2003.0  ...     8450        65.0
# 1        284         460          RFn       1976.0  ...     9600        80.0
# 2        434         608          RFn       2001.0  ...    11250        68.0
#
#    MasVnrArea  OpenPorchSF  OverallCond  OverallQual  TotalBsmtSF  YearBuilt  \
# 0       196.0           61            5            7          856       2003
# 1         0.0            0            8            6         1262       1976
# 2       162.0           42            5            7          920       2001
#
#    YearRemodAdd  Clusters
# 0          2003         2
# 1          1976        48
# 2          2002         2
#
# [3 rows x 22 columns]

# %%
print(f"* Clusters frequencies \n{ X['Clusters'].value_counts(normalize=True).to_frame().round(2)} \n\n")
X['Clusters'].value_counts().sort_values().plot(kind='bar')
plt.show()
# Out:
# * Clusters frequencies
#     Clusters
# 7       0.04
# 22      0.04
# 43      0.04
# 28      0.04
# 17      0.04
# 3       0.03
# 2       0.03
# 5       0.03
# 18      0.03
# 9       0.03
# 48      0.03
# 6       0.03
# 39      0.03
# 1       0.03
# 23      0.03
# 33      0.03
# 14      0.03
# 47      0.02
# 10      0.02
# 21      0.02
# 42      0.02
# 30      0.02
# 19      0.02
# 38      0.02
# 24      0.02
# 36      0.02
# 26      0.02
# 41      0.02
# 16      0.02
# 11      0.02
# 34      0.02
# 45      0.02
# 20      0.01
# 15      0.01
# 4       0.01
# 31      0.01
# 46      0.01
# 40      0.01
# 8       0.01
# 32      0.01
# 49      0.01
# 44      0.01
# 27      0.01
# 37      0.00
# 13      0.00
# 29      0.00
# 0       0.00
# 25      0.00
# 35      0.00
# 12      0.00

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_analysis[:, 0], y=df_analysis[:, 1],
                hue=X['Clusters'], palette='Set1', alpha=0.6)
plt.scatter(x=pipeline_cluster['model'].cluster_centers_[:, 0], y=pipeline_cluster['model'].cluster_centers_[:, 1],
            marker="x", s=169, linewidths=3, color="black")
plt.xlabel("PCA Component 0")
plt.ylabel("PCA Component 1")
plt.title("PCA Components colored by Clusters")
plt.show()

# %% [markdown]
# We save the cluster predictions from this pipeline to use in the future. We will get back to that in a later stage.

# %%
cluster_predictions_with_all_variables = X['Clusters']
cluster_predictions_with_all_variables
# Out:
# 0        2
# 1       48
# 2        2
# 3       24
# 4        9
#         ..
# 1455    33
# 1456    31
# 1457    36
# 1458    47
# 1459    43
# Name: Clusters, Length: 1460, dtype: int32

# %% [markdown]
# ## Fit a classifier, where the target is cluster predictions and features remaining variables

# %% [markdown]
# We copy `X` to a DataFrame `df_clf`

# %%
df_clf = X.copy()
print(df_clf.shape)
df_clf.head(3)
# Out:
# (1460, 22)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
#
#    BsmtUnfSF  GarageArea GarageFinish  GarageYrBlt  ...  LotArea LotFrontage  \
# 0        150         548          RFn       2003.0  ...     8450        65.0
# 1        284         460          RFn       1976.0  ...     9600        80.0
# 2        434         608          RFn       2001.0  ...    11250        68.0
#
#    MasVnrArea  OpenPorchSF  OverallCond  OverallQual  TotalBsmtSF  YearBuilt  \
# 0       196.0           61            5            7          856       2003
# 1         0.0            0            8            6         1262       1976
# 2       162.0           42            5            7          920       2001
#
#    YearRemodAdd  Clusters
# 0          2003         2
# 1          1976        48
# 2          2002         2
#
# [3 rows x 22 columns]

# %% [markdown]
# Split Train and Test sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df_clf.drop(['Clusters'], axis=1),
    df_clf['Clusters'],
    test_size=0.2,
    random_state=0
)

print(X_train.shape, X_test.shape)
# Out:
# (1168, 21) (292, 21)

# %% [markdown]
# Create classifier pipeline steps

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from feature_engine.encoding import OrdinalEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import GradientBoostingClassifier
from feature_engine.imputation import CategoricalImputer
from sklearn.tree import DecisionTreeClassifier  
from feature_engine.selection import DropFeatures  

def PipelineClf2ExplainClusters():
    pipeline_base = Pipeline([

        ('median', MeanMedianImputer(imputation_method='median',
                                     variables=['2ndFlrSF', 'BedroomAbvGr','GarageYrBlt', 
                                                'LotFrontage', 'MasVnrArea'])),
        
        ('categorical_imputer', CategoricalImputer(imputation_method='missing',
                                                  fill_value='Missing',
                                                  variables=['GarageFinish', 'BsmtFinType1'])),
        
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary',
                                                     variables=['BsmtExposure', 'GarageFinish', 'KitchenQual', 'BsmtFinType1'])),
        ("scaler", StandardScaler()),
        
        ('feat_selection', SelectFromModel(estimator=DecisionTreeClassifier(random_state=0))),
                
        ('model', DecisionTreeClassifier(random_state=0)), 
    ])
    return pipeline_base

PipelineClf2ExplainClusters()
# Out:
# Pipeline(steps=[('median',
#                  MeanMedianImputer(variables=['2ndFlrSF', 'BedroomAbvGr',
#                                               'GarageYrBlt', 'LotFrontage',
#                                               'MasVnrArea'])),
#                 ('categorical_imputer',
#                  CategoricalImputer(variables=['GarageFinish',
#                                                'BsmtFinType1'])),
#                 ('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['BsmtExposure', 'GarageFinish',
#                                            'KitchenQual', 'BsmtFinType1'])),
#                 ('scaler', StandardScaler()),
#                 ('feat_selection',
#                  SelectFromModel(estimator=DecisionTreeClassifier(random_state=0))),
#                 ('model', DecisionTreeClassifier(random_state=0))])

# %%
pipeline_clf_cluster = PipelineClf2ExplainClusters()
pipeline_clf_cluster.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('median',
#                  MeanMedianImputer(variables=['2ndFlrSF', 'BedroomAbvGr',
#                                               'GarageYrBlt', 'LotFrontage',
#                                               'MasVnrArea'])),
#                 ('categorical_imputer',
#                  CategoricalImputer(variables=['GarageFinish',
#                                                'BsmtFinType1'])),
#                 ('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['BsmtExposure', 'GarageFinish',
#                                            'KitchenQual', 'BsmtFinType1'])),
#                 ('scaler', StandardScaler()),
#                 ('feat_selection',
#                  SelectFromModel(estimator=DecisionTreeClassifier(random_state=0))),
#                 ('model', DecisionTreeClassifier(random_state=0))])

# %% [markdown]
# ## Evaluate classifier performance on Train and Test Sets

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train, pipeline_clf_cluster.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00        34
#            2       1.00      1.00      1.00        37
#            3       1.00      1.00      1.00        39
#            4       1.00      1.00      1.00        13
#            5       1.00      1.00      1.00        36
#            6       1.00      1.00      1.00        35
#            7       1.00      1.00      1.00        49
#            8       1.00      1.00      1.00        13
#            9       1.00      1.00      1.00        29
#           10       1.00      1.00      1.00        25
#           11       1.00      1.00      1.00        17
#           13       1.00      1.00      1.00         5
#           14       1.00      1.00      1.00        36
#           15       1.00      1.00      1.00        17
#           16       1.00      1.00      1.00        18
#           17       1.00      1.00      1.00        46
#           18       1.00      1.00      1.00        40
#           19       1.00      1.00      1.00        30
#           20       1.00      1.00      1.00        20
#           21       1.00      1.00      1.00        28
#           22       1.00      1.00      1.00        54
#           23       1.00      1.00      1.00        32
#           24       1.00      1.00      1.00        22
#           25       1.00      1.00      1.00         3
#           26       1.00      1.00      1.00        20
#           27       1.00      1.00      1.00         6
#           28       1.00      1.00      1.00        47
#           29       1.00      1.00      1.00         4
#           30       1.00      1.00      1.00        26
#           31       1.00      1.00      1.00        12
#           32       1.00      1.00      1.00        13
#           33       1.00      1.00      1.00        36
#           34       1.00      1.00      1.00        19
#           35       1.00      1.00      1.00         1
#           36       1.00      1.00      1.00        21
#           37       1.00      1.00      1.00         5
#           38       1.00      1.00      1.00        24
#           39       1.00      1.00      1.00        34
#           40       1.00      1.00      1.00        11
#           41       1.00      1.00      1.00        24
#           42       1.00      1.00      1.00        27
#           43       1.00      1.00      1.00        50
#           44       1.00      1.00      1.00         9
#           45       1.00      1.00      1.00        16
#           46       1.00      1.00      1.00        10
#           47       1.00      1.00      1.00        26
#           48       1.00      1.00      1.00        35
#           49       1.00      1.00      1.00        11
#
#     accuracy                           1.00      1168
#    macro avg       1.00      1.00      1.00      1168
# weighted avg       1.00      1.00      1.00      1168

# %%
print(classification_report(y_test, pipeline_clf_cluster.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.56      0.50      0.53        10
#            2       0.77      0.91      0.83        11
#            3       0.17      0.10      0.12        10
#            4       0.40      0.40      0.40         5
#            5       0.64      0.75      0.69        12
#            6       0.38      0.50      0.43        10
#            7       0.70      0.54      0.61        13
#            8       0.50      0.50      0.50         2
#            9       0.50      0.39      0.44        18
#           10       0.09      0.12      0.11         8
#           11       0.43      0.43      0.43         7
#           12       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         1
#           14       0.00      0.00      0.00         5
#           15       0.20      0.25      0.22         4
#           16       0.71      0.71      0.71         7
#           17       0.25      0.11      0.15         9
#           18       0.33      0.38      0.35         8
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         1
#           21       0.62      1.00      0.77         5
#           22       0.27      0.57      0.36         7
#           23       0.89      0.80      0.84        10
#           24       0.50      0.50      0.50         6
#           26       0.50      0.33      0.40         6
#           27       0.00      0.00      0.00         2
#           28       0.60      0.69      0.64        13
#           29       0.00      0.00      0.00         2
#           30       0.83      1.00      0.91         5
#           31       1.00      0.25      0.40         4
#           32       0.00      0.00      0.00         2
#           33       0.50      0.40      0.44         5
#           34       0.29      0.40      0.33         5
#           36       1.00      0.40      0.57         5
#           37       1.00      0.50      0.67         2
#           38       0.67      0.50      0.57         4
#           39       0.70      0.70      0.70        10
#           40       0.57      1.00      0.73         4
#           41       0.50      1.00      0.67         2
#           42       0.20      0.25      0.22         4
#           43       0.15      0.18      0.17        11
#           44       0.00      0.00      0.00         2
#           45       0.80      0.67      0.73         6
#           46       0.67      0.40      0.50         5
#           47       0.14      0.11      0.12         9
#           48       0.25      0.18      0.21        11
#           49       0.50      0.33      0.40         3
#
#     accuracy                           0.46       292
#    macro avg       0.42      0.40      0.39       292
# weighted avg       0.47      0.46      0.45       292
# /home/codeany/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/codeany/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/codeany/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/codeany/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/codeany/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/codeany/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Assess the most important Features that define a cluster

# %%
data_cleaning_feat_eng_steps = 2
columns_after_data_cleaning_feat_eng = (Pipeline(pipeline_clf_cluster.steps[:data_cleaning_feat_eng_steps])
                                        .transform(X_train)
                                        .columns)

best_features = columns_after_data_cleaning_feat_eng[pipeline_clf_cluster['feat_selection'].get_support(
)].to_list()

df_feature_importance = (pd.DataFrame(data={
    'Feature': columns_after_data_cleaning_feat_eng[pipeline_clf_cluster['feat_selection'].get_support()],
    'Importance': pipeline_clf_cluster['model'].feature_importances_})
    .sort_values(by='Importance', ascending=False)
)

best_features = df_feature_importance['Feature'].to_list()

print(f"* These are the {len(best_features)} most important features in descending order. "
      f"The model was trained on them: \n{best_features} \n")
df_feature_importance.plot(kind='bar', x='Feature', y='Importance')
plt.show()
# Out:
# * These are the 9 most important features in descending order. The model was trained on them:
# ['TotalBsmtSF', 'YearBuilt', 'BsmtFinType1', 'GrLivArea', 'GarageArea', 'LotArea', 'BsmtExposure', 'GarageFinish', '2ndFlrSF']

# %%
best_features_pipeline_all_variables = best_features
best_features_pipeline_all_variables
# Out:
# ['TotalBsmtSF',
#  'YearBuilt',
#  'BsmtFinType1',
#  'GrLivArea',
#  'GarageArea',
#  'LotArea',
#  'BsmtExposure',
#  'GarageFinish',
#  '2ndFlrSF']

# %% [markdown]
# ## Cluster Analysis

# %% [markdown]
# Load function that plots a table with description for all Clusters

# %%
def DescriptionAllClusters(df, decimal_points=3):

    DescriptionAllClusters = pd.DataFrame(
        columns=df.drop(['Clusters'], axis=1).columns)
    for cluster in df.sort_values(by='Clusters')['Clusters'].unique():

        EDA_ClusterSubset = df.query(
            f"Clusters == {cluster}").drop(['Clusters'], axis=1)
        ClusterDescription = Clusters_IndividualDescription(
            EDA_ClusterSubset, cluster, decimal_points)
        DescriptionAllClusters = DescriptionAllClusters.append(
            ClusterDescription)

    DescriptionAllClusters.set_index(['Cluster'], inplace=True)
    return DescriptionAllClusters

def Clusters_IndividualDescription(EDA_Cluster, cluster, decimal_points):

    ClustersDescription = pd.DataFrame(columns=EDA_Cluster.columns)

    for col in EDA_Cluster.columns:

        try: 

            if EDA_Cluster[col].dtypes == 'object':

                top_frequencies = EDA_Cluster.dropna(
                    subset=[col])[[col]].value_counts(normalize=True).nlargest(n=3)
                Description = ''

                for x in range(len(top_frequencies)):
                    freq = top_frequencies.iloc[x]
                    category = top_frequencies.index[x][0]
                    CategoryPercentage = int(round(freq*100, 0))
                    statement = f"'{category}': {CategoryPercentage}% , "
                    Description = Description + statement

                ClustersDescription.at[0, col] = Description[:-2]

            elif EDA_Cluster[col].dtypes in ['float', 'int']:
                DescStats = EDA_Cluster.dropna(subset=[col])[[col]].describe()
                Q1 = round(DescStats.iloc[4, 0], decimal_points)
                Q3 = round(DescStats.iloc[6, 0], decimal_points)
                Description = f"{Q1} -- {Q3}"
                ClustersDescription.at[0, col] = Description

        except Exception as e:
            ClustersDescription.at[0, col] = 'Not available'
            print(
                f"** Error Exception: {e} - cluster {cluster}, variable {col}")

    ClustersDescription['Cluster'] = str(cluster)

    return ClustersDescription

# %% [markdown]
# Load a custom function to plot cluster distribution per Variable (absolute and relative levels)

# %%
import plotly.express as px


def cluster_distribution_per_variable(df, target):
    df_bar_plot = df.value_counts(["Clusters", target]).reset_index()
    df_bar_plot.columns = ['Clusters', target, 'Count']
    df_bar_plot[target] = df_bar_plot[target].astype('object')

    print(f"Clusters distribution across {target} levels")
    fig = px.bar(df_bar_plot, x='Clusters', y='Count',
                 color=target, width=800, height=500)
    fig.update_layout(xaxis=dict(tickmode='array',
                      tickvals=df['Clusters'].unique()))
    fig.show(renderer='colab')

    df_relative = (df
                   .groupby(["Clusters", target])
                   .size()
                   .groupby(level=0)
                   .apply(lambda x:  100*x / x.sum())
                   .reset_index()
                   .sort_values(by=['Clusters'])
                   )
    df_relative.columns = ['Clusters', target, 'Relative Percentage (%)']

    print(f"Relative Percentage (%) of {target} in each cluster")
    fig = px.line(df_relative, x='Clusters', y='Relative Percentage (%)',
                  color=target, width=800, height=500)
    fig.update_layout(xaxis=dict(tickmode='array',
                      tickvals=df['Clusters'].unique()))
    fig.update_traces(mode='markers+lines')
    fig.show(renderer='colab')

# %% [markdown]
# Create a DataFrame that contains best features and Clusters Predictions since we want to analyse the patterns for each cluster.

# %%
df_cluster_profile = df_clf.copy()
df_cluster_profile = df_cluster_profile.filter(items=best_features + ['Clusters'], axis=1)
print(df_cluster_profile.shape)
df_cluster_profile.head(3)
# Out:
# (1460, 10)
#    TotalBsmtSF  YearBuilt BsmtFinType1  GrLivArea  GarageArea  LotArea  \
# 0          856       2003          GLQ       1710         548     8450
# 1         1262       1976          ALQ       1262         460     9600
# 2          920       2001          GLQ       1786         608    11250
#
#   BsmtExposure GarageFinish  2ndFlrSF  Clusters
# 0           No          RFn     854.0         2
# 1           Gd          RFn       0.0        48
# 2           Mn          RFn     866.0         2

# %% [markdown]
# We want also to analyse Churn levels.

# %%
df_sales = pd.read_csv("outputs/datasets/collection/SalesRecord.csv").filter(['SalePrice'])
df_sales['SalePrice'] = df_sales['SalePrice']
df_sales.head(3)
# Out:
#    SalePrice
# 0     208500
# 1     181500
# 2     223500

# %% [markdown]
# ### Cluster profile based on the best features

# %%
pd.set_option('display.max_colwidth', None)
clusters_profile = DescriptionAllClusters(df=pd.concat([df_cluster_profile,df_sales], axis=1), decimal_points=0)
clusters_profile
# Out:
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
#               TotalBsmtSF         YearBuilt  \
# Cluster
# 0         918.0 -- 1288.0  1886.0 -- 1914.0
# 1        1237.0 -- 1565.0  1959.0 -- 1968.0
# 2          788.0 -- 970.0  1996.0 -- 2002.0
# 3          651.0 -- 876.0  1918.0 -- 1932.0
# 4          522.0 -- 695.0  1935.0 -- 1970.0
# 5        1233.0 -- 1370.0  2003.0 -- 2006.0
# 6        1208.0 -- 1478.0  1993.0 -- 2005.0
# 7          728.0 -- 936.0  1997.0 -- 2004.0
# 8        1152.0 -- 1608.0  2002.0 -- 2006.0
# 9        1368.0 -- 1566.0  1996.0 -- 2005.0
# 10        912.0 -- 1144.0  1948.0 -- 1961.0
# 11       1006.0 -- 1181.0  2002.0 -- 2006.0
# 12       6110.0 -- 6110.0  2008.0 -- 2008.0
# 13       1406.0 -- 1627.0  1958.0 -- 1980.0
# 14        864.0 -- 1092.0  1955.0 -- 1971.0
# 15        954.0 -- 1360.0  1928.0 -- 1973.0
# 16         796.0 -- 868.0  1998.0 -- 2005.0
# 17       1068.0 -- 1270.0  1958.0 -- 1972.0
# 18         700.0 -- 951.0  1922.0 -- 1942.0
# 19       1203.0 -- 1439.0  1990.0 -- 1998.0
# 20       1654.0 -- 1922.0  2002.0 -- 2006.0
# 21             0.0 -- 0.0  1949.0 -- 1960.0
# 22         735.0 -- 941.0  1920.0 -- 1941.0
# 23         686.0 -- 994.0  1922.0 -- 1971.0
# 24         616.0 -- 816.0  1910.0 -- 1928.0
# 25       1472.0 -- 1818.0  1962.0 -- 1965.0
# 26       1480.0 -- 1693.0  2005.0 -- 2006.0
# 27        859.0 -- 1305.0  1909.0 -- 1968.0
# 28         864.0 -- 994.0  1962.0 -- 1977.0
# 29       1868.0 -- 2432.0  1995.0 -- 2004.0
# 30         483.0 -- 750.0  1971.0 -- 1976.0
# 31       1610.0 -- 2122.0  1967.0 -- 1979.0
# 32        970.0 -- 1342.0  1958.0 -- 1976.0
# 33         689.0 -- 924.0  2000.0 -- 2005.0
# 34       1460.0 -- 1728.0  2005.0 -- 2007.0
# 35         585.0 -- 585.0  1960.0 -- 1960.0
# 36        800.0 -- 1048.0  1917.0 -- 1940.0
# 37       1530.0 -- 1869.0  1996.0 -- 2004.0
# 38        989.0 -- 1158.0  1957.0 -- 1972.0
# 39         750.0 -- 872.0  1964.0 -- 1974.0
# 40        748.0 -- 1056.0  1910.0 -- 1936.0
# 41         738.0 -- 933.0  1997.0 -- 2005.0
# 42       1464.0 -- 1628.0  2001.0 -- 2007.0
# 43         771.0 -- 955.0  1945.0 -- 1967.0
# 44        756.0 -- 1038.0  1997.0 -- 2000.0
# 45       1296.0 -- 1581.0  1959.0 -- 1977.0
# 46       1685.0 -- 2044.0  2006.0 -- 2008.0
# 47        897.0 -- 1126.0  1950.0 -- 1960.0
# 48        844.0 -- 1094.0  1963.0 -- 1977.0
# 49       1842.0 -- 2221.0  2004.0 -- 2008.0
#
#                                   BsmtFinType1         GrLivArea  \
# Cluster
# 0                     'Unf': 67% , 'Rec': 33%   3470.0 -- 3550.0
# 1        'Unf': 60% , 'Rec': 15% , 'ALQ': 10%   1368.0 -- 1684.0
# 2                      'GLQ': 92% , 'ALQ': 8%   1686.0 -- 1948.0
# 3         'Unf': 67% , 'BLQ': 13% , 'ALQ': 7%   1111.0 -- 1601.0
# 4        'GLQ': 29% , 'ALQ': 14% , 'BLQ': 14%     630.0 -- 853.0
# 5         'Unf': 51% , 'GLQ': 44% , 'ALQ': 4%   1252.0 -- 1419.0
# 6                      'GLQ': 91% , 'ALQ': 9%   1241.0 -- 1593.0
# 7         'Unf': 70% , 'GLQ': 23% , 'ALQ': 6%   1484.0 -- 1929.0
# 8                     'Unf': 85% , 'GLQ': 15%   2493.0 -- 2845.0
# 9          'GLQ': 91% , 'ALQ': 7% , 'BLQ': 2%   1434.0 -- 1631.0
# 10        'LwQ': 60% , 'BLQ': 37% , 'Rec': 3%   1092.0 -- 1487.0
# 11        'Unf': 70% , 'GLQ': 22% , 'BLQ': 4%   1934.0 -- 2386.0
# 12                                'GLQ': 100%   5642.0 -- 5642.0
# 13       'GLQ': 50% , 'BLQ': 33% , 'ALQ': 17%   1669.0 -- 1838.0
# 14        'ALQ': 60% , 'GLQ': 30% , 'Rec': 5%   1040.0 -- 1381.0
# 15       'BLQ': 26% , 'LwQ': 21% , 'Rec': 21%   2112.0 -- 2624.0
# 16                     'GLQ': 96% , 'ALQ': 4%    848.0 -- 1146.0
# 17       'Rec': 47% , 'ALQ': 34% , 'BLQ': 11%   1120.0 -- 1384.0
# 18       'Unf': 63% , 'ALQ': 13% , 'Rec': 13%    801.0 -- 1054.0
# 19                     'GLQ': 93% , 'ALQ': 7%   2285.0 -- 2642.0
# 20                                'GLQ': 100%   1654.0 -- 1922.0
# 21                    'None': 97% , 'BLQ': 3%   1040.0 -- 1535.0
# 22        'Unf': 67% , 'Rec': 15% , 'ALQ': 8%   1376.0 -- 1738.0
# 23       'Unf': 46% , 'ALQ': 16% , 'BLQ': 14%    864.0 -- 1286.0
# 24        'Unf': 84% , 'Rec': 12% , 'ALQ': 4%   1176.0 -- 1541.0
# 25                    'ALQ': 50% , 'Rec': 50%   1911.0 -- 2090.0
# 26                    'Unf': 62% , 'GLQ': 38%   1486.0 -- 1698.0
# 27       'ALQ': 33% , 'LwQ': 33% , 'Unf': 33%   2248.0 -- 2654.0
# 28       'ALQ': 53% , 'GLQ': 22% , 'Unf': 17%    894.0 -- 1069.0
# 29                    'GLQ': 83% , 'ALQ': 17%   3366.0 -- 4436.0
# 30       'ALQ': 41% , 'BLQ': 22% , 'Unf': 22%   1040.0 -- 1365.0
# 31       'ALQ': 50% , 'GLQ': 21% , 'Rec': 21%   2101.0 -- 2517.0
# 32       'ALQ': 40% , 'BLQ': 20% , 'GLQ': 20%    970.0 -- 1562.0
# 33         'Unf': 86% , 'GLQ': 5% , 'ALQ': 3%   1456.0 -- 1709.0
# 34                                'GLQ': 100%   1724.0 -- 2194.0
# 35                                'GLQ': 100%   2069.0 -- 2069.0
# 36       'Unf': 42% , 'Rec': 29% , 'BLQ': 17%   2114.0 -- 2590.0
# 37                    'GLQ': 86% , 'ALQ': 14%   1530.0 -- 1869.0
# 38       'BLQ': 62% , 'LwQ': 21% , 'Rec': 17%   1022.0 -- 1360.0
# 39       'Rec': 29% , 'ALQ': 21% , 'Unf': 21%   1736.0 -- 1977.0
# 40        'Unf': 79% , 'LwQ': 14% , 'ALQ': 7%   1790.0 -- 2220.0
# 41        'GLQ': 50% , 'Unf': 42% , 'ALQ': 4%   1520.0 -- 1930.0
# 42                    'Unf': 80% , 'GLQ': 20%   1496.0 -- 1735.0
# 43       'BLQ': 52% , 'Rec': 27% , 'LwQ': 21%    913.0 -- 1256.0
# 44       'GLQ': 60% , 'Unf': 30% , 'ALQ': 10%   1464.0 -- 1971.0
# 45       'ALQ': 35% , 'BLQ': 35% , 'LwQ': 20%   1495.0 -- 1779.0
# 46                    'Unf': 79% , 'GLQ': 21%   1696.0 -- 2044.0
# 47       'BLQ': 48% , 'LwQ': 35% , 'Rec': 16%    932.0 -- 1294.0
# 48        'ALQ': 64% , 'GLQ': 29% , 'Rec': 4%    910.0 -- 1193.0
# 49                     'GLQ': 92% , 'ALQ': 8%   1842.0 -- 2231.0
#
#                GarageArea               LotArea  \
# Cluster
# 0          855.0 -- 942.0    16243.0 -- 20668.0
# 1          440.0 -- 528.0     9593.0 -- 11726.0
# 2          482.0 -- 593.0     8459.0 -- 11383.0
# 3          216.0 -- 288.0     6000.0 -- 10200.0
# 4            0.0 -- 302.0      2422.0 -- 9328.0
# 5          430.0 -- 528.0      3562.0 -- 8800.0
# 6          472.0 -- 586.0     5063.0 -- 12327.0
# 7          412.0 -- 528.0     8124.0 -- 11077.0
# 8          656.0 -- 815.0    11132.0 -- 14306.0
# 9          504.0 -- 632.0     7748.0 -- 10956.0
# 10         286.0 -- 440.0     8500.0 -- 11409.0
# 11         578.0 -- 857.0    10360.0 -- 14169.0
# 12       1418.0 -- 1418.0    63887.0 -- 63887.0
# 13         540.0 -- 698.0    53137.0 -- 67371.0
# 14         288.0 -- 528.0     7758.0 -- 10140.0
# 15         528.0 -- 672.0     9525.0 -- 15863.0
# 16         420.0 -- 525.0      4426.0 -- 7314.0
# 17         436.0 -- 538.0     8858.0 -- 11250.0
# 18         240.0 -- 360.0      6150.0 -- 9015.0
# 19         621.0 -- 833.0     9965.0 -- 12240.0
# 20         691.0 -- 866.0    10437.0 -- 13891.0
# 21         287.0 -- 516.0     7200.0 -- 10125.0
# 22         240.0 -- 379.0     6435.0 -- 10120.0
# 23             0.0 -- 0.0      5944.0 -- 9550.0
# 24         483.0 -- 628.0     6210.0 -- 10440.0
# 25         451.0 -- 521.0  161830.0 -- 189952.0
# 26         555.0 -- 838.0     8811.0 -- 11084.0
# 27         432.0 -- 603.0    10710.0 -- 17107.0
# 28         308.0 -- 573.0     7194.0 -- 10389.0
# 29         808.0 -- 839.0    20707.0 -- 39010.0
# 30         264.0 -- 440.0      1680.0 -- 2280.0
# 31         506.0 -- 583.0    12673.0 -- 20120.0
# 32         360.0 -- 552.0     7707.0 -- 16239.0
# 33         457.0 -- 528.0      3604.0 -- 9313.0
# 34         738.0 -- 847.0    10740.0 -- 13201.0
# 35         505.0 -- 505.0    27650.0 -- 27650.0
# 36         296.0 -- 532.0    10024.0 -- 13559.0
# 37         598.0 -- 789.0    12949.0 -- 16448.0
# 38         330.0 -- 497.0     9462.0 -- 12996.0
# 39         442.0 -- 515.0     9335.0 -- 11763.0
# 40             0.0 -- 0.0      6252.0 -- 9200.0
# 41         411.0 -- 607.0     9028.0 -- 11882.0
# 42         544.0 -- 797.0    10188.0 -- 12206.0
# 43         276.0 -- 400.0      7500.0 -- 9937.0
# 44         440.0 -- 610.0      2645.0 -- 9375.0
# 45         481.0 -- 582.0    10357.0 -- 14730.0
# 46         604.0 -- 837.0     9744.0 -- 13582.0
# 47         288.0 -- 484.0      6996.0 -- 9882.0
# 48         368.0 -- 573.0     7863.0 -- 10710.0
# 49        695.0 -- 1008.0    11512.0 -- 14752.0
#
#                                  BsmtExposure  \
# Cluster
# 0                      'Mn': 67% , 'No': 33%
# 1            'No': 93% , 'Av': 5% , 'Gd': 2%
# 2            'No': 85% , 'Gd': 6% , 'Av': 4%
# 3                       'No': 94% , 'Mn': 6%
# 4        'Av': 50% , 'No': 17% , 'None': 17%
# 5          'No': 62% , 'Av': 21% , 'Mn': 10%
# 6           'No': 67% , 'Gd': 24% , 'Av': 4%
# 7                       'No': 98% , 'Gd': 2%
# 8          'No': 53% , 'Av': 20% , 'Gd': 20%
# 9          'Av': 62% , 'Mn': 19% , 'Gd': 15%
# 10           'No': 88% , 'Gd': 6% , 'Mn': 6%
# 11         'Av': 46% , 'Mn': 33% , 'No': 17%
# 12                                'Gd': 100%
# 13                     'Gd': 67% , 'Av': 33%
# 14           'No': 90% , 'Gd': 5% , 'Mn': 5%
# 15          'No': 76% , 'Gd': 10% , 'Av': 5%
# 16          'Av': 60% , 'Gd': 24% , 'Mn': 8%
# 17                     'No': 85% , 'Gd': 15%
# 18           'No': 88% , 'Mn': 8% , 'Av': 4%
# 19         'No': 63% , 'Gd': 17% , 'Av': 10%
# 20                     'Gd': 57% , 'No': 43%
# 21                    'None': 97% , 'Av': 3%
# 22                      'No': 92% , 'Mn': 8%
# 23          'No': 83% , 'Gd': 12% , 'Av': 2%
# 24                     'No': 89% , 'Mn': 11%
# 25                                'Gd': 100%
# 26                      'Av': 92% , 'Mn': 8%
# 27         'No': 75% , 'Av': 12% , 'Mn': 12%
# 28                     'No': 88% , 'Gd': 12%
# 29         'Gd': 67% , 'Av': 17% , 'No': 17%
# 30           'No': 94% , 'Gd': 3% , 'Mn': 3%
# 31         'No': 38% , 'Av': 31% , 'Gd': 19%
# 32          'No': 60% , 'Gd': 27% , 'Av': 7%
# 33                      'No': 95% , 'Av': 5%
# 34         'No': 42% , 'Av': 25% , 'Gd': 25%
# 35                                'Gd': 100%
# 36          'No': 81% , 'Mn': 15% , 'Gd': 4%
# 37                     'Av': 71% , 'Mn': 29%
# 38                     'Av': 68% , 'Mn': 32%
# 39           'No': 84% , 'Gd': 7% , 'Mn': 7%
# 40         'No': 67% , 'Av': 20% , 'Mn': 13%
# 41        'Av': 65% , 'Mn': 31% , 'None': 4%
# 42                     'No': 90% , 'Gd': 10%
# 43           'No': 92% , 'Mn': 5% , 'Gd': 3%
# 44                      'No': 91% , 'Av': 9%
# 45           'No': 82% , 'Gd': 9% , 'Mn': 9%
# 46          'No': 60% , 'Gd': 27% , 'Av': 7%
# 47         'No': 71% , 'Mn': 17% , 'Gd': 11%
# 48          'Av': 78% , 'Mn': 15% , 'Gd': 7%
# 49         'Gd': 43% , 'Av': 36% , 'No': 14%
#
#                                    GarageFinish          2ndFlrSF  \
# Cluster
# 0                                  'Unf': 100%   1498.0 -- 1668.0
# 1          'Unf': 51% , 'RFn': 44% , 'Fin': 3%         0.0 -- 0.0
# 2          'RFn': 80% , 'Unf': 15% , 'Fin': 5%     833.0 -- 944.0
# 3          'Unf': 89% , 'None': 4% , 'RFn': 4%     175.0 -- 668.0
# 4        'None': 54% , 'Unf': 31% , 'Fin': 15%         0.0 -- 0.0
# 5         'Fin': 56% , 'RFn': 32% , 'Unf': 12%         0.0 -- 0.0
# 6         'Fin': 67% , 'RFn': 17% , 'Unf': 14%         0.0 -- 0.0
# 7                                  'Fin': 100%     728.0 -- 930.0
# 8                       'Fin': 93% , 'RFn': 7%   1116.0 -- 1330.0
# 9          'RFn': 79% , 'Fin': 12% , 'Unf': 9%         0.0 -- 0.0
# 10         'Unf': 77% , 'RFn': 19% , 'Fin': 3%       0.0 -- 223.0
# 11                      'RFn': 91% , 'Unf': 9%    855.0 -- 1156.0
# 12                                 'Fin': 100%     950.0 -- 950.0
# 13                     'Fin': 50% , 'Unf': 50%         0.0 -- 0.0
# 14        'Unf': 54% , 'RFn': 31% , 'Fin': 14%         0.0 -- 0.0
# 15        'Unf': 62% , 'Fin': 25% , 'RFn': 12%    966.0 -- 1230.0
# 16        'Fin': 42% , 'Unf': 32% , 'RFn': 26%         0.0 -- 0.0
# 17         'Unf': 51% , 'RFn': 47% , 'Fin': 2%         0.0 -- 0.0
# 18          'Unf': 89% , 'RFn': 9% , 'Fin': 2%         0.0 -- 0.0
# 19        'RFn': 48% , 'Fin': 39% , 'Unf': 13%    896.0 -- 1330.0
# 20         'RFn': 50% , 'Fin': 44% , 'Unf': 6%         0.0 -- 0.0
# 21        'Unf': 71% , 'None': 19% , 'Fin': 6%         0.0 -- 0.0
# 22          'Unf': 96% , 'Fin': 2% , 'RFn': 2%     520.0 -- 746.0
# 23                                'None': 100%         0.0 -- 0.0
# 24                                 'Unf': 100%     316.0 -- 622.0
# 25                     'Fin': 67% , 'RFn': 33%      84.0 -- 434.0
# 26         'RFn': 85% , 'Fin': 10% , 'Unf': 5%         0.0 -- 0.0
# 27        'Unf': 62% , 'RFn': 25% , 'Fin': 12%    842.0 -- 1030.0
# 28        'Unf': 77% , 'Fin': 12% , 'RFn': 12%         0.0 -- 0.0
# 29                                 'Fin': 100%   1551.0 -- 1853.0
# 30         'Unf': 79% , 'Fin': 10% , 'RFn': 7%     504.0 -- 668.0
# 31        'Unf': 38% , 'Fin': 31% , 'RFn': 31%         0.0 -- 0.0
# 32        'RFn': 43% , 'Unf': 36% , 'Fin': 14%         0.0 -- 0.0
# 33                     'RFn': 85% , 'Unf': 15%     670.0 -- 807.0
# 34                      'Fin': 95% , 'RFn': 5%       0.0 -- 905.0
# 35                                 'RFn': 100%         0.0 -- 0.0
# 36        'Unf': 71% , 'Fin': 19% , 'RFn': 10%    819.0 -- 1150.0
# 37                                 'Fin': 100%         0.0 -- 0.0
# 38        'Unf': 50% , 'RFn': 29% , 'Fin': 21%         0.0 -- 0.0
# 39        'RFn': 53% , 'Unf': 29% , 'Fin': 18%     734.0 -- 896.0
# 40                    'None': 80% , 'Unf': 20%     761.0 -- 960.0
# 41          'Fin': 88% , 'Unf': 8% , 'RFn': 4%     728.0 -- 900.0
# 42        'RFn': 67% , 'Fin': 23% , 'Unf': 10%         0.0 -- 0.0
# 43         'Unf': 76% , 'RFn': 16% , 'Fin': 7%       0.0 -- 325.0
# 44         'RFn': 45% , 'Unf': 45% , 'Fin': 9%     729.0 -- 920.0
# 45                     'Fin': 86% , 'Unf': 14%         0.0 -- 0.0
# 46                     'Fin': 54% , 'RFn': 46%         0.0 -- 0.0
# 47         'Unf': 73% , 'RFn': 21% , 'Fin': 6%         0.0 -- 0.0
# 48         'Unf': 57% , 'RFn': 36% , 'Fin': 7%         0.0 -- 0.0
# 49                     'Fin': 85% , 'RFn': 15%         0.0 -- 0.0
#
#                     SalePrice
# Cluster
# 0        338000.0 -- 428000.0
# 1        139400.0 -- 165000.0
# 2        196000.0 -- 235250.0
# 3        112000.0 -- 155000.0
# 4         84600.0 -- 117625.0
# 5        172312.0 -- 200731.0
# 6        180000.0 -- 245500.0
# 7        176125.0 -- 224375.0
# 8        286000.0 -- 424390.0
# 9        200000.0 -- 255500.0
# 10       113000.0 -- 141000.0
# 11       232048.0 -- 282500.0
# 12       160000.0 -- 160000.0
# 13       244000.0 -- 296500.0
# 14       136500.0 -- 170000.0
# 15       142953.0 -- 225000.0
# 16       141000.0 -- 155900.0
# 17       139000.0 -- 166000.0
# 18        80000.0 -- 113375.0
# 19       274000.0 -- 336750.0
# 20       262000.0 -- 326000.0
# 21        87500.0 -- 115000.0
# 22       108000.0 -- 145000.0
# 23        85000.0 -- 117250.0
# 24       116675.0 -- 148644.0
# 25       252975.0 -- 326000.0
# 26       195500.0 -- 248757.0
# 27       154500.0 -- 260742.0
# 28       120500.0 -- 140250.0
# 29       462366.0 -- 715000.0
# 30        91250.0 -- 136500.0
# 31       215250.0 -- 273425.0
# 32       132750.0 -- 183300.0
# 33       160000.0 -- 191000.0
# 34       317375.0 -- 383840.0
# 35       242000.0 -- 242000.0
# 36       187875.0 -- 250000.0
# 37       259500.0 -- 297500.0
# 38       130812.0 -- 155500.0
# 39       155000.0 -- 192375.0
# 40       120250.0 -- 143450.0
# 41       184250.0 -- 219802.0
# 42       203000.0 -- 247500.0
# 43       112000.0 -- 136000.0
# 44       172500.0 -- 229250.0
# 45       176625.0 -- 216875.0
# 46       265066.0 -- 375500.0
# 47       128500.0 -- 152500.0
# 48       132625.0 -- 159875.0
# 49       368970.0 -- 455625.0

# %% [markdown]
# ### Clusters distribution across Churn levels & Relative Percentage of Churn in each cluster

# %%
df_cluster_vs_sales=  df_sales.copy()
df_cluster_vs_sales['Clusters'] = X['Clusters']
cluster_distribution_per_variable(df=df_cluster_vs_sales, target='SalePrice')
# Out:
# Clusters distribution across SalePrice levels
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="0b860cc5-9b0a-4672-8eb4-c1933d13513c" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b860cc5-9b0a-4672-8eb4-c1933d13513c")) {                    Plotly.newPlot(                        "0b860cc5-9b0a-4672-8eb4-c1933d13513c",                        [{"alignmentgroup": "True", "hovertemplate": "SalePrice=110000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "110000", "marker": {"color": "#636efa"}, "name": "110000", "offsetgroup": "110000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [43, 28, 10, 24, 1, 3], "xaxis": "x", "y": [4, 2, 2, 2, 2, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=140000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "140000", "marker": {"color": "#EF553B"}, "name": "140000", "offsetgroup": "140000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [28, 24, 16, 3, 17, 1, 43, 39, 5, 22, 10], "xaxis": "x", "y": [4, 3, 2, 2, 2, 2, 1, 1, 1, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=120500<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "120500", "marker": {"color": "#00cc96"}, "name": "120500", "offsetgroup": "120500", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [28, 4], "xaxis": "x", "y": [3, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=135000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "135000", "marker": {"color": "#ab63fa"}, "name": "135000", "offsetgroup": "135000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3, 15, 17, 22, 47, 23, 28, 43, 1, 14, 10], "xaxis": "x", "y": [3, 2, 2, 2, 2, 1, 1, 1, 1, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=139000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "139000", "marker": {"color": "#FFA15A"}, "name": "139000", "offsetgroup": "139000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [17, 10, 48, 24, 43, 40], "xaxis": "x", "y": [3, 3, 2, 1, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=175000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "175000", "marker": {"color": "#19d3f3"}, "name": "175000", "offsetgroup": "175000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [48, 9, 33, 39, 22, 2], "xaxis": "x", "y": [3, 2, 1, 1, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=147000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "147000", "marker": {"color": "#FF6692"}, "name": "147000", "offsetgroup": "147000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [14, 30, 24, 23, 26, 28, 16], "xaxis": "x", "y": [3, 1, 1, 1, 1, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=120000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "120000", "marker": {"color": "#B6E880"}, "name": "120000", "offsetgroup": "120000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [43, 32, 22, 21, 14], "xaxis": "x", "y": [3, 1, 1, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=180000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "180000", "marker": {"color": "#FF97FF"}, "name": "180000", "offsetgroup": "180000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [6, 7, 31, 33, 28, 45, 1], "xaxis": "x", "y": [3, 2, 1, 1, 1, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Sale ...
# Relative Percentage (%) of SalePrice in each cluster
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="61fdbf12-170e-4572-ab6d-ef78ec768830" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61fdbf12-170e-4572-ab6d-ef78ec768830")) {                    Plotly.newPlot(                        "61fdbf12-170e-4572-ab6d-ef78ec768830",                        [{"hovertemplate": "SalePrice=295000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "295000", "line": {"color": "#636efa", "dash": "solid"}, "mode": "markers+lines", "name": "295000", "showlegend": true, "type": "scattergl", "x": [0], "xaxis": "x", "y": [33.333333333333336], "yaxis": "y"}, {"hovertemplate": "SalePrice=381000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "381000", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "markers+lines", "name": "381000", "showlegend": true, "type": "scattergl", "x": [0], "xaxis": "x", "y": [33.333333333333336], "yaxis": "y"}, {"hovertemplate": "SalePrice=475000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "475000", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "markers+lines", "name": "475000", "showlegend": true, "type": "scattergl", "x": [0], "xaxis": "x", "y": [33.333333333333336], "yaxis": "y"}, {"hovertemplate": "SalePrice=153500<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "153500", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "markers+lines", "name": "153500", "showlegend": true, "type": "scattergl", "x": [1, 6, 17], "xaxis": "x", "y": [2.272727272727273, 2.2222222222222223, 1.8181818181818181], "yaxis": "y"}, {"hovertemplate": "SalePrice=155000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "155000", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "markers+lines", "name": "155000", "showlegend": true, "type": "scattergl", "x": [1, 2, 3, 5, 6, 14, 30, 38, 39, 43, 47, 48], "xaxis": "x", "y": [2.272727272727273, 2.0833333333333335, 2.0408163265306123, 2.0833333333333335, 2.2222222222222223, 2.4390243902439024, 3.225806451612903, 3.5714285714285716, 4.545454545454546, 1.639344262295082, 2.857142857142857, 4.3478260869565215], "yaxis": "y"}, {"hovertemplate": "SalePrice=156500<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "156500", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "markers+lines", "name": "156500", "showlegend": true, "type": "scattergl", "x": [1], "xaxis": "x", "y": [2.272727272727273], "yaxis": "y"}, {"hovertemplate": "SalePrice=157900<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "157900", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "markers+lines", "name": "157900", "showlegend": true, "type": "scattergl", "x": [1, 43], "xaxis": "x", "y": [2.272727272727273, 1.639344262295082], "yaxis": "y"}, {"hovertemplate": "SalePrice=159000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "159000", "line": {"color": "#B6E880", "dash": "solid"}, "mode": "markers+lines", "name": "159000", "showlegend": true, "type": "scattergl", "x": [1, 6, 14, 22], "xaxis": "x", "y": [2.272727272727273, 2.2222222222222223, 2.4390243902439024, 1.639344262295082], "yaxis": "y"}, {"hovertemplate": "SalePrice=160000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "160000", "line": {"color": "#FF97FF", "dash": "solid"}, "mode": "markers+lines", "name": "160000", "showlegend": true, "type": "scattergl", "x": [1, 12, 13, 15, 17, 30, 33, 40, 43, 48], "xaxis": "x", "y": [4.545454545454546, 100.0, 16.666666666666668, 4.761904761904762, 3.6363636363636362, 3.225806451612903, 2.4390243902439024, 6.666666666666667, 1 ...

# %% [markdown]
# # Fit New Cluster Pipeline with most important features

# %% [markdown]
# In order to reduce feature space, we will study the trade-off between the previous Cluster Pipeline (fitted with all variables) and Pipeline using the variables that are most important to define the clusters from the previous pipeline

# %%
best_features_pipeline_all_variables
# Out:
# ['TotalBsmtSF',
#  'YearBuilt',
#  'BsmtFinType1',
#  'GrLivArea',
#  'GarageArea',
#  'LotArea',
#  'BsmtExposure',
#  'GarageFinish',
#  '2ndFlrSF']

# %% [markdown]
# ## Subset data with the most relevant variables

# %%
df_reduced = df.filter(best_features_pipeline_all_variables)
df_reduced.head(3)
# Out:
#    TotalBsmtSF  YearBuilt BsmtFinType1  GrLivArea  GarageArea  LotArea  \
# 0          856       2003          GLQ       1710         548     8450
# 1         1262       1976          ALQ       1262         460     9600
# 2          920       2001          GLQ       1786         608    11250
#
#   BsmtExposure GarageFinish  2ndFlrSF
# 0           No          RFn     854.0
# 1           Gd          RFn       0.0
# 2           Mn          RFn     866.0

# %% [markdown]
# ## Rewrite Cluster Pipeline

# %%
def PipelineCluster():
    pipeline_base = Pipeline([

       ('median', MeanMedianImputer(imputation_method='median',
                                     variables=['2ndFlrSF'])),
        
        ('categorical_imputer', CategoricalImputer(imputation_method='missing',
                                                  fill_value='Missing',
                                                  variables=['GarageFinish', 'BsmtFinType1'])),
        
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary',
                                                     variables=['BsmtExposure', 'GarageFinish', 'BsmtFinType1'])),
        ("scaler", StandardScaler()),

        ("model", KMeans(n_clusters=3, random_state=0)),
    ])
    return pipeline_base


PipelineCluster()
# Out:
# Pipeline(steps=[('median', MeanMedianImputer(variables=['2ndFlrSF'])),
#                 ('categorical_imputer',
#                  CategoricalImputer(variables=['GarageFinish',
#                                                'BsmtFinType1'])),
#                 ('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['BsmtExposure', 'GarageFinish',
#                                            'BsmtFinType1'])),
#                 ('scaler', StandardScaler()),
#                 ('model', KMeans(n_clusters=3, random_state=0))])

# %% [markdown]
# ## Apply Elbow Method and Silhouette analysis

# %%
pipeline_cluster = PipelineCluster()
pipeline_analysis = Pipeline(pipeline_cluster.steps[:-1])
df_analysis = pipeline_analysis.fit_transform(df_reduced)

print(df_analysis.shape,'\n', type(df_analysis))
# Out:
# (1460, 9)
#  <class 'numpy.ndarray'>

# %%
from yellowbrick.cluster import KElbowVisualizer
visualizer = KElbowVisualizer(KMeans(random_state=0), k=(1,11))
visualizer.fit(df_analysis) 
visualizer.show() 
plt.show()

# %%
from yellowbrick.cluster import SilhouetteVisualizer

n_cluster_start, n_cluster_stop = 2, 5

print("=== Average Silhouette Score for different number of clusters ===")
visualizer = KElbowVisualizer(KMeans(random_state=0), k=(
    n_cluster_start, n_cluster_stop), metric='silhouette')
visualizer.fit(df_analysis)
visualizer.show()
plt.show()
print("\n")


for n_clusters in np.arange(start=n_cluster_start, stop=n_cluster_stop):

    print(f"=== Silhouette plot for {n_clusters} Clusters ===")
    visualizer = SilhouetteVisualizer(estimator=KMeans(n_clusters=n_clusters, random_state=0),
                                      colors='yellowbrick')
    visualizer.fit(df_analysis)
    visualizer.show()
    plt.show()
    print("\n")
# Out:
# === Average Silhouette Score for different number of clusters ===
# /home/codeany/.local/lib/python3.8/site-packages/yellowbrick/utils/kneed.py:155: YellowbrickWarning:
#
# No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#
# /home/codeany/.local/lib/python3.8/site-packages/yellowbrick/cluster/elbow.py:343: YellowbrickWarning:
#
# No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
# === Silhouette plot for 2 Clusters ===
# === Silhouette plot for 3 Clusters ===
# === Silhouette plot for 4 Clusters ===

# %% [markdown]
# ## Fit New Cluster Pipeline

# %% [markdown]
# We set X as our training set for the cluster. It is a copy of df_reduced

# %%
X = df_reduced.copy()
print(X.shape)
X.head(3)
# Out:
# (1460, 9)
#    TotalBsmtSF  YearBuilt BsmtFinType1  GrLivArea  GarageArea  LotArea  \
# 0          856       2003          GLQ       1710         548     8450
# 1         1262       1976          ALQ       1262         460     9600
# 2          920       2001          GLQ       1786         608    11250
#
#   BsmtExposure GarageFinish  2ndFlrSF
# 0           No          RFn     854.0
# 1           Gd          RFn       0.0
# 2           Mn          RFn     866.0

# %%
pipeline_cluster = PipelineCluster()
pipeline_cluster.fit(X)
# Out:
# Pipeline(steps=[('median', MeanMedianImputer(variables=['2ndFlrSF'])),
#                 ('categorical_imputer',
#                  CategoricalImputer(variables=['GarageFinish',
#                                                'BsmtFinType1'])),
#                 ('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['BsmtExposure', 'GarageFinish',
#                                            'BsmtFinType1'])),
#                 ('scaler', StandardScaler()),
#                 ('model', KMeans(n_clusters=3, random_state=0))])

# %% [markdown]
# ## Add cluster predictions to dataset

# %% [markdown]
# We add a column "`Clusters`" (with the cluster pipeline predictions) to the dataset

# %%
X['Clusters'] = pipeline_cluster['model'].labels_
print(X.shape)
X.head(3)
# Out:
# (1460, 10)
#    TotalBsmtSF  YearBuilt BsmtFinType1  GrLivArea  GarageArea  LotArea  \
# 0          856       2003          GLQ       1710         548     8450
# 1         1262       1976          ALQ       1262         460     9600
# 2          920       2001          GLQ       1786         608    11250
#
#   BsmtExposure GarageFinish  2ndFlrSF  Clusters
# 0           No          RFn     854.0         1
# 1           Gd          RFn       0.0         2
# 2           Mn          RFn     866.0         1

# %%
print(f"* Clusters frequencies \n{ X['Clusters'].value_counts(normalize=True).to_frame().round(2)} \n\n")
X['Clusters'].value_counts().sort_values().plot(kind='bar')
plt.show()
# Out:
# * Clusters frequencies
#    Clusters
# 0      0.43
# 2      0.31
# 1      0.26

# %% [markdown]
# ## Compare current cluster predictions to previous cluster predictions

# %%
cluster_predictions_with_all_variables
# Out:
# 0        2
# 1       48
# 2        2
# 3       24
# 4        9
#         ..
# 1455    33
# 1456    31
# 1457    36
# 1458    47
# 1459    43
# Name: Clusters, Length: 1460, dtype: int32

# %%
cluster_predictions_with_best_features = X['Clusters'] 
cluster_predictions_with_best_features
# Out:
# 0       1
# 1       2
# 2       1
# 3       0
# 4       2
#        ..
# 1455    1
# 1456    2
# 1457    1
# 1458    0
# 1459    0
# Name: Clusters, Length: 1460, dtype: int32

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(cluster_predictions_with_all_variables, cluster_predictions_with_best_features))
# Out:
# [[ 0  3  0 ...  0  0  0]
#  [21  0 23 ...  0  0  0]
#  [ 0 48  0 ...  0  0  0]
#  ...
#  [34  1  0 ...  0  0  0]
#  [15  1 30 ...  0  0  0]
#  [ 0  0 14 ...  0  0  0]]

# %% [markdown]
# ## Fit a classifier, where the target is cluster predictions and features remaining variables

# %%
df_clf = X.copy()
print(df_clf.shape)
df_clf.head(3)
# Out:
# (1460, 10)
#    TotalBsmtSF  YearBuilt BsmtFinType1  GrLivArea  GarageArea  LotArea  \
# 0          856       2003          GLQ       1710         548     8450
# 1         1262       1976          ALQ       1262         460     9600
# 2          920       2001          GLQ       1786         608    11250
#
#   BsmtExposure GarageFinish  2ndFlrSF  Clusters
# 0           No          RFn     854.0         1
# 1           Gd          RFn       0.0         2
# 2           Mn          RFn     866.0         1

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df_clf.drop(['Clusters'], axis=1),
    df_clf['Clusters'],
    test_size=0.2,
    random_state=0
)

print(X_train.shape, X_test.shape)
# Out:
# (1168, 9) (292, 9)

# %% [markdown]
# Rewrite pipeline to explain clusters

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from feature_engine.encoding import OrdinalEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import GradientBoostingClassifier
from feature_engine.imputation import CategoricalImputer
from sklearn.tree import DecisionTreeClassifier  
from feature_engine.selection import DropFeatures  

def PipelineClf2ExplainClusters():
    pipeline_base = Pipeline([

        ('median', MeanMedianImputer(imputation_method='median',
                                     variables=['2ndFlrSF'])),
        
        ('categorical_imputer', CategoricalImputer(imputation_method='missing',
                                                  fill_value='Missing',
                                                  variables=['GarageFinish', 'BsmtFinType1'])),
        
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary',
                                                     variables=['BsmtExposure', 'GarageFinish','BsmtFinType1'])),
        ("scaler", StandardScaler()),
        
        ('feat_selection', SelectFromModel(estimator=DecisionTreeClassifier(random_state=0))),
                
        ('model', DecisionTreeClassifier(random_state=0)),  

    ])
    return pipeline_base

PipelineClf2ExplainClusters()
# Out:
# Pipeline(steps=[('median', MeanMedianImputer(variables=['2ndFlrSF'])),
#                 ('categorical_imputer',
#                  CategoricalImputer(variables=['GarageFinish',
#                                                'BsmtFinType1'])),
#                 ('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['BsmtExposure', 'GarageFinish',
#                                            'BsmtFinType1'])),
#                 ('scaler', StandardScaler()),
#                 ('feat_selection',
#                  SelectFromModel(estimator=DecisionTreeClassifier(random_state=0))),
#                 ('model', DecisionTreeClassifier(random_state=0))])

# %% [markdown]
# ## Fit a classifier, where the target is cluster labels and features remaining variables

# %%
pipeline_clf_cluster = PipelineClf2ExplainClusters()
pipeline_clf_cluster.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('median', MeanMedianImputer(variables=['2ndFlrSF'])),
#                 ('categorical_imputer',
#                  CategoricalImputer(variables=['GarageFinish',
#                                                'BsmtFinType1'])),
#                 ('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['BsmtExposure', 'GarageFinish',
#                                            'BsmtFinType1'])),
#                 ('scaler', StandardScaler()),
#                 ('feat_selection',
#                  SelectFromModel(estimator=DecisionTreeClassifier(random_state=0))),
#                 ('model', DecisionTreeClassifier(random_state=0))])

# %% [markdown]
# ## Evaluate classifier performance on Train and Test Sets

# %%
print(classification_report(y_train, pipeline_clf_cluster.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       501
#            1       1.00      1.00      1.00       314
#            2       1.00      0.99      0.99       353
#
#     accuracy                           0.99      1168
#    macro avg       1.00      0.99      0.99      1168
# weighted avg       0.99      0.99      0.99      1168

# %%
print(classification_report(y_test, pipeline_clf_cluster.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88       129
#            1       0.94      0.94      0.94        70
#            2       0.85      0.82      0.84        93
#
#     accuracy                           0.88       292
#    macro avg       0.89      0.88      0.89       292
# weighted avg       0.88      0.88      0.88       292

# %% [markdown]
# ## Cluster Analysis

# %%
df_cluster_profile = df_clf.copy()
df_cluster_profile = df_cluster_profile.filter(items=best_features + ['Clusters'], axis=1)
df_cluster_profile.head(3)
# Out:
#    TotalBsmtSF  YearBuilt BsmtFinType1  GrLivArea  GarageArea  LotArea  \
# 0          856       2003          GLQ       1710         548     8450
# 1         1262       1976          ALQ       1262         460     9600
# 2          920       2001          GLQ       1786         608    11250
#
#   BsmtExposure GarageFinish  2ndFlrSF  Clusters
# 0           No          RFn     854.0         1
# 1           Gd          RFn       0.0         2
# 2           Mn          RFn     866.0         1

# %%
df_sales = pd.read_csv("outputs/datasets/collection/SalesRecord.csv").filter(['SalePrice'])
df_sales['SalePrice'] = df_sales['SalePrice']
df_sales.head(3)
# Out:
#    SalePrice
# 0     208500
# 1     181500
# 2     223500

# %% [markdown]
# ### Cluster profile on most important features

# %%
pd.set_option('display.max_colwidth', None)
clusters_profile = DescriptionAllClusters(df= pd.concat([df_cluster_profile,df_sales], axis=1), decimal_points=0)
clusters_profile
# Out:
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_4790/2106555119.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#               TotalBsmtSF         YearBuilt  \
# Cluster
# 0         686.0 -- 1040.0  1930.0 -- 1965.0
# 1         777.0 -- 1114.0  1975.0 -- 2003.0
# 2        1197.0 -- 1629.0  1977.0 -- 2006.0
#
#                                   BsmtFinType1         GrLivArea  \
# Cluster
# 0        'Unf': 30% , 'BLQ': 20% , 'ALQ': 16%    951.0 -- 1392.0
# 1         'Unf': 40% , 'GLQ': 37% , 'ALQ': 8%   1704.0 -- 2286.0
# 2        'GLQ': 55% , 'ALQ': 20% , 'Unf': 20%   1259.0 -- 1704.0
#
#              GarageArea            LotArea  \
# Cluster
# 0        240.0 -- 449.0  6916.0 -- 10200.0
# 1        440.0 -- 652.0  8754.0 -- 12400.0
# 2        484.0 -- 680.0  8076.0 -- 12472.0
#
#                                BsmtExposure  \
# Cluster
# 0          'No': 77% , 'Mn': 7% , 'Av': 7%
# 1         'No': 71% , 'Av': 12% , 'Mn': 8%
# 2        'No': 44% , 'Av': 29% , 'Gd': 19%
#
#                                    GarageFinish         2ndFlrSF  \
# Cluster
# 0        'Unf': 67% , 'RFn': 15% , 'None': 12%      0.0 -- 504.0
# 1         'Fin': 40% , 'RFn': 36% , 'Unf': 23%   756.0 -- 1068.0
# 2         'RFn': 41% , 'Fin': 37% , 'Unf': 22%        0.0 -- 0.0
#
#                     SalePrice
# Cluster
# 0        108969.0 -- 144000.0
# 1        174000.0 -- 254925.0
# 2        169992.0 -- 255375.0

# %% [markdown]
# ### Clusters distribution across Churn levels & Relative Percentage of Churn in each cluster

# %%
df_cluster_vs_sales=  df_sales.copy()
df_cluster_vs_sales['Clusters'] = X['Clusters']
cluster_distribution_per_variable(df=df_cluster_vs_sales, target='SalePrice')
# Out:
# Clusters distribution across SalePrice levels
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="40afd2fe-ef7f-40c7-8641-363315cf96b9" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40afd2fe-ef7f-40c7-8641-363315cf96b9")) {                    Plotly.newPlot(                        "40afd2fe-ef7f-40c7-8641-363315cf96b9",                        [{"alignmentgroup": "True", "hovertemplate": "SalePrice=135000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "135000", "marker": {"color": "#636efa"}, "name": "135000", "offsetgroup": "135000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0, 2, 1], "xaxis": "x", "y": [14, 2, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=140000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "140000", "marker": {"color": "#EF553B"}, "name": "140000", "offsetgroup": "140000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0, 2, 1], "xaxis": "x", "y": [14, 5, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=115000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "115000", "marker": {"color": "#00cc96"}, "name": "115000", "offsetgroup": "115000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0], "xaxis": "x", "y": [12], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=110000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "110000", "marker": {"color": "#ab63fa"}, "name": "110000", "offsetgroup": "110000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0, 2], "xaxis": "x", "y": [10, 3], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=127000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "127000", "marker": {"color": "#FFA15A"}, "name": "127000", "offsetgroup": "127000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0], "xaxis": "x", "y": [9], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=155000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "155000", "marker": {"color": "#19d3f3"}, "name": "155000", "offsetgroup": "155000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0, 2, 1], "xaxis": "x", "y": [9, 3, 2], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=100000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "100000", "marker": {"color": "#FF6692"}, "name": "100000", "offsetgroup": "100000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0], "xaxis": "x", "y": [9], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=139000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "139000", "marker": {"color": "#B6E880"}, "name": "139000", "offsetgroup": "139000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0, 2, 1], "xaxis": "x", "y": [9, 1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=125000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "125000", "marker": {"color": "#FF97FF"}, "name": "125000", "offsetgroup": "125000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0, 2], "xaxis": "x", "y": [8, 2], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=130000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "130000", "marker": {"color": "#FECB52"}, "name": "130000", "offsetgroup": "130000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0, 1], "xaxis": "x", "y": [8, 3], "yaxis": "y"}, { ...
# Relative Percentage (%) of SalePrice in each cluster
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="1d430ec9-dbd5-4aad-a6a1-8ab26f73db06" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d430ec9-dbd5-4aad-a6a1-8ab26f73db06")) {                    Plotly.newPlot(                        "1d430ec9-dbd5-4aad-a6a1-8ab26f73db06",                        [{"hovertemplate": "SalePrice=34900<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "34900", "line": {"color": "#636efa", "dash": "solid"}, "mode": "markers+lines", "name": "34900", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.15873015873015872], "yaxis": "y"}, {"hovertemplate": "SalePrice=142500<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "142500", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "markers+lines", "name": "142500", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0, 2], "xaxis": "x", "y": [0.15873015873015872, 0.4484304932735426], "yaxis": "y"}, {"hovertemplate": "SalePrice=142125<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "142125", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "markers+lines", "name": "142125", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.15873015873015872], "yaxis": "y"}, {"hovertemplate": "SalePrice=142000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "142000", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "markers+lines", "name": "142000", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.6349206349206349], "yaxis": "y"}, {"hovertemplate": "SalePrice=141500<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "141500", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "markers+lines", "name": "141500", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.15873015873015872], "yaxis": "y"}, {"hovertemplate": "SalePrice=141000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "141000", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "markers+lines", "name": "141000", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0, 2], "xaxis": "x", "y": [1.1111111111111112, 0.2242152466367713], "yaxis": "y"}, {"hovertemplate": "SalePrice=140200<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "140200", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "markers+lines", "name": "140200", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.15873015873015872], "yaxis": "y"}, {"hovertemplate": "SalePrice=142600<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "142600", "line": {"color": "#B6E880", "dash": "solid"}, "mode": "markers+lines", "name": "142600", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.15873015873015872], "yaxis": "y"}, {"hovertemplate": "SalePrice=140000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "140000", "line": {"color": "#FF97FF", "dash": "solid"}, "mode": "markers+lines", "name": "140000", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0, 1, 2], "xaxis": "x", "y": [2.2222222222222223, 0.2604166666666667, 1.1210762331838564], "yaxis": "y"}, {"hovertemplate": "SalePrice=139900<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "139900", "line": {"color": "#FECB52", "dash": "solid"}, "mode": "markers+lines", "name": "139900", "orientation": "v", "showlegend": true, "type": "scatter", "x ...

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# We will generate the following files
#
# * Cluster Pipeline
# * Train Set
# * Feature importance plot
# * Clusters Description
# * Cluster Silhouette

# %%
import joblib
import os

version = 'v1'
file_path = f'outputs/ml_pipeline/cluster_analysis/{version}'

try:
    os.makedirs(name=file_path)
except Exception as e:
    print(e)

# %% [markdown]
# ## Cluster pipeline

# %%
joblib.dump(value=pipeline_cluster, filename=f"{file_path}/cluster_pipeline.pkl")
# Out:
# ['outputs/ml_pipeline/cluster_analysis/v1/cluster_pipeline.pkl']

# %% [markdown]
# ## Train Set

# %%
print(df_reduced.shape)
df_reduced.head(3)
# Out:
# (1460, 9)
#    TotalBsmtSF  YearBuilt BsmtFinType1  GrLivArea  GarageArea  LotArea  \
# 0          856       2003          GLQ       1710         548     8450
# 1         1262       1976          ALQ       1262         460     9600
# 2          920       2001          GLQ       1786         608    11250
#
#   BsmtExposure GarageFinish  2ndFlrSF
# 0           No          RFn     854.0
# 1           Gd          RFn       0.0
# 2           Mn          RFn     866.0

# %%
df_reduced.to_csv(f"{file_path}/TrainSet.csv", index=False)

# %% [markdown]
# ## Most important features plot

# %%
df_feature_importance.plot(kind='bar',x='Feature',y='Importance', figsize=(8,4))
plt.show()

# %%
df_feature_importance.plot(kind='bar',x='Feature',y='Importance', figsize=(8,4))
plt.savefig(f"{file_path}/features_define_cluster.png", bbox_inches='tight', dpi=150)

# %% [markdown]
# ## Cluster Profile

# %%
clusters_profile
# Out:
#               TotalBsmtSF         YearBuilt  \
# Cluster
# 0         686.0 -- 1040.0  1930.0 -- 1965.0
# 1         777.0 -- 1114.0  1975.0 -- 2003.0
# 2        1197.0 -- 1629.0  1977.0 -- 2006.0
#
#                                   BsmtFinType1         GrLivArea  \
# Cluster
# 0        'Unf': 30% , 'BLQ': 20% , 'ALQ': 16%    951.0 -- 1392.0
# 1         'Unf': 40% , 'GLQ': 37% , 'ALQ': 8%   1704.0 -- 2286.0
# 2        'GLQ': 55% , 'ALQ': 20% , 'Unf': 20%   1259.0 -- 1704.0
#
#              GarageArea            LotArea  \
# Cluster
# 0        240.0 -- 449.0  6916.0 -- 10200.0
# 1        440.0 -- 652.0  8754.0 -- 12400.0
# 2        484.0 -- 680.0  8076.0 -- 12472.0
#
#                                BsmtExposure  \
# Cluster
# 0          'No': 77% , 'Mn': 7% , 'Av': 7%
# 1         'No': 71% , 'Av': 12% , 'Mn': 8%
# 2        'No': 44% , 'Av': 29% , 'Gd': 19%
#
#                                    GarageFinish         2ndFlrSF  \
# Cluster
# 0        'Unf': 67% , 'RFn': 15% , 'None': 12%      0.0 -- 504.0
# 1         'Fin': 40% , 'RFn': 36% , 'Unf': 23%   756.0 -- 1068.0
# 2         'RFn': 41% , 'Fin': 37% , 'Unf': 22%        0.0 -- 0.0
#
#                     SalePrice
# Cluster
# 0        108969.0 -- 144000.0
# 1        174000.0 -- 254925.0
# 2        169992.0 -- 255375.0

# %%
clusters_profile.to_csv(f"{file_path}/clusters_profile.csv")

# %% [markdown]
# ## Cluster silhouette plot

# %%
visualizer = SilhouetteVisualizer(Pipeline(pipeline_cluster.steps[-1:])[0] , colors='yellowbrick')
visualizer.fit(df_analysis)
visualizer.show()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(7,5))
fig = SilhouetteVisualizer(Pipeline(pipeline_cluster.steps[-1:])[0] , colors='yellowbrick', ax=axes)
fig.fit(df_analysis)

plt.savefig(f"{file_path}/clusters_silhouette.png", bbox_inches='tight',dpi=150)
